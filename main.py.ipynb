# %%
from barycentric import generateMorphBarycentric
from measureDifference import getOptimalSequence
import cv2
import numpy as np

endIndex = 15
seq = getOptimalSequence(endIndex)
finalImg = cv2.imread('./dataSet/test_' + str(seq[0])+'.png')	# append very first img
# Out:
# calculating 0 1...
# (82953, ' ', 40.64121373494818)
# ('Total diff between img', 0, 1, ' ', ' is ', 317.15121373494816)
# calculating 0 2...
# (28566, ' ', 39.54449971516904)
# ('Total diff between img', 0, 2, ' ', ' is ', 134.76449971516905)
# calculating 0 3...
# (57636, ' ', 40.20404815674487)
# ('Total diff between img', 0, 3, ' ', ' is ', 232.32404815674488)
# calculating 0 4...
# (67087, ' ', 38.245143890382415)
# ('Total diff between img', 0, 4, ' ', ' is ', 261.86847722371573)
# calculating 0 5...
# (106345, ' ', 39.13250478108753)
# ('Total diff between img', 0, 5, ' ', ' is ', 393.61583811442085)
# calculating 0 6...
# (60650, ' ', 43.88415908813457)
# ('Total diff between img', 0, 6, ' ', ' is ', 246.05082575480122)
# calculating 0 7...
# (30488, ' ', 42.631844838470634)
# ('Total diff between img', 0, 7, ' ', ' is ', 144.2585115051373)
# calculating 0 8...
# (33475, ' ', 43.03441238403122)
# ('Total diff between img', 0, 8, ' ', ' is ', 154.61774571736456)
# calculating 0 9...
# (23655, ' ', 42.663358052572825)
# ('Total diff between img', 0, 9, ' ', ' is ', 121.51335805257281)
# calculating 0 10...
# (128969, ' ', 40.91731516519969)
# ('Total diff between img', 0, 10, ' ', ' is ', 470.81398183186633)
# calculating 0 11...
# (27191, ' ', 41.18288040160993)
# ('Total diff between img', 0, 11, ' ', ' is ', 131.8195470682766)
# calculating 0 12...
# (40034, ' ', 45.290968577060504)
# ('Total diff between img', 0, 12, ' ', ' is ', 178.73763524372717)
# calculating 0 13...
# (145224, ' ', 45.66263071695855)
# ('Total diff between img', 0, 13, ' ', ' is ', 529.7426307169585)
# calculating 0 14...
# (112891, ' ', 41.84584299723408)
# ('Total diff between img', 0, 14, ' ', ' is ', 418.1491763305674)
# calculating 1 2...
# (110063, ' ', 46.03284327192225)
# ('Total diff between img', 1, 2, ' ', ' is ', 412.90950993858894)
# calculating 1 3...
# (133421, ' ', 45.431975046780934)
# ('Total diff between img', 1, 3, ' ', ' is ', 490.16864171344764)
# calculating 1 4...
# (167278, ' ', 44.64689890543614)
# ('Total diff between img', 1, 4, ' ', ' is ', 602.2402322387695)
# calculating 1 5...
# (187832, ' ', 45.415119171154124)
# ('Total diff between img', 1, 5, ' ', ' is ', 671.5217858378209)
# calculating 1 6...
# (212249, ' ', 41.64789326985563)
# ('Total diff between img', 1, 6, ' ', ' is ', 749.1445599365223)
# calculating 1 7...
# (170373, ' ', 38.150461832670835)
# ('Total diff between img', 1, 7, ' ', ' is ', 606.0604618326709)
# calculating 1 8...
# (155846, ' ', 48.20732625326078)
# ('Total diff between img', 1, 8, ' ', ' is ', 567.6939929199275)
# calculating 1 9...
# (78136, ' ', 40.640959421796595)
# ('Total diff between img', 1, 9, ' ', ' is ', 301.0942927551299)
# calculating 1 10...
# (165976, ' ', 42.637429555230106)
# ('Total diff between img', 1, 10, ' ', ' is ', 595.8907628885635)
# calculating 1 11...
# (104230, ' ', 42.20833333333088)
# ('Total diff between img', 1, 11, ' ', ' is ', 389.6416666666642)
# calculating 1 12...
# (138035, ' ', 41.4303538004529)
# ('Total diff between img', 1, 12, ' ', ' is ', 501.5470204671196)
# calculating 1 13...
# (296687, ' ', 37.74342219035688)
# ('Total diff between img', 1, 13, ' ', ' is ', 1026.7000888570235)
# calculating 1 14...
# (247180, ' ', 43.218626658115404)
# ('Total diff between img', 1, 14, ' ', ' is ', 867.1519599914487)
# calculating 2 3...
# (44238, ' ', 42.606814066562016)
# ('Total diff between img', 2, 3, ' ', ' is ', 190.06681406656202)
# calculating 2 4...
# (65511, ' ', 40.838665008532004)
# ('Total diff between img', 2, 4, ' ', ' is ', 259.208665008532)
# calculating 2 5...
# (93529, ' ', 37.76020558673694)
# ('Total diff between img', 2, 5, ' ', ' is ', 349.5235389200703)
# calculating 2 6...
# (38506, ' ', 42.14890416463181)
# ('Total diff between img', 2, 6, ' ', ' is ', 170.50223749796513)
# calculating 2 7...
# (35222, ' ', 39.979923248294114)
# ('Total diff between img', 2, 7, ' ', ' is ', 157.38658991496078)
# calculating 2 8...
# (37801, ' ', 46.98861058553051)
# ('Total diff between img', 2, 8, ' ', ' is ', 172.99194391886385)
# calculating 2 9...
# (15791, ' ', 40.94112396240378)
# ('Total diff between img', 2, 9, ' ', ' is ', 93.57779062907045)
# calculating 2 10...
# (119119, ' ', 41.06259409586487)
# ('Total diff between img', 2, 10, ' ', ' is ', 438.1259274291982)
# calculating 2 11...
# (11973, ' ', 45.12926610311168)
# ('Total diff between img', 2, 11, ' ', ' is ', 85.03926610311169)
# calculating 2 12...
# (28162, ' ', 39.531299591045446)
# ('Total diff between img', 2, 12, ' ', ' is ', 133.40463292437877)
# calculating 2 13...
# (119062, ' ', 45.001920064298716)
# ('Total diff between img', 2, 13, ' ', ' is ', 441.87525339763204)
# calculating 2 14...
# (94973, ' ', 42.20401255289721)
# ('Total diff between img', 2, 14, ' ', ' is ', 358.78067921956386)
# calculating 3 4...
# (103495, ' ', 41.752358754480085)
# ('Total diff between img', 3, 4, ' ', ' is ', 386.73569208781345)
# calculating 3 5...
# (114027, ' ', 41.06908162434561)
# ('Total diff between img', 3, 5, ' ', ' is ', 421.15908162434556)
# calculating 3 6...
# (67218, ' ', 45.59417343139639)
# ('Total diff between img', 3, 6, ' ', ' is ', 269.6541734313964)
# calculating 3 7...
# (84108, ' ', 40.40663782755963)
# ('Total diff between img', 3, 7, ' ', ' is ', 320.76663782755963)
# calculating 3 8...
# (55913, ' ', 48.25158818562917)
# ('Total diff between img', 3, 8, ' ', ' is ', 234.62825485229584)
# calculating 3 9...
# (62209, ' ', 42.26302083333454)
# ('Total diff between img', 3, 9, ' ', ' is ', 249.62635416666788)
# calculating 3 10...
# (150057, ' ', 41.63286336263415)
# ('Total diff between img', 3, 10, ' ', ' is ', 541.8228633626342)
# calculating 3 11...
# (68861, ' ', 42.21548589070672)
# ('Total diff between img', 3, 11, ' ', ' is ', 271.7521525573734)
# calculating 3 12...
# (46822, ' ', 44.7607485453202)
# ('Total diff between img', 3, 12, ' ', ' is ', 200.83408187865354)
# calculating 3 13...
# (143476, ' ', 42.75382995605268)
# ('Total diff between img', 3, 13, ' ', ' is ', 521.007163289386)
# calculating 3 14...
# (111071, ' ', 43.09589640299492)
# ('Total diff between img', 3, 14, ' ', ' is ', 413.3325630696616)
# calculating 4 5...
# (20902, ' ', 36.289053599042674)
# ('Total diff between img', 4, 5, ' ', ' is ', 105.962386932376)
# calculating 4 6...
# (28711, ' ', 44.48992665608603)
# ('Total diff between img', 4, 6, ' ', ' is ', 140.19325998941935)
# calculating 4 7...
# (74759, ' ', 40.035138448061396)
# ('Total diff between img', 4, 7, ' ', ' is ', 289.23180511472805)
# calculating 4 8...
# (25264, ' ', 44.56628672282481)
# ('Total diff between img', 4, 8, ' ', ' is ', 128.77962005615814)
# calculating 4 9...
# (108564, ' ', 38.28572718302445)
# ('Total diff between img', 4, 9, ' ', ' is ', 400.16572718302444)
# calculating 4 10...
# (33684, ' ', 42.306611378968384)
# ('Total diff between img', 4, 10, ' ', ' is ', 154.58661137896837)
# calculating 4 11...
# (70604, ' ', 43.993726094561)
# ('Total diff between img', 4, 11, ' ', ' is ', 279.3403927612277)
# calculating 4 12...
# (22675, ' ', 38.30233510335697)
# ('Total diff between img', 4, 12, ' ', ' is ', 113.8856684366903)
# calculating 4 13...
# (32783, ' ', 43.49821599325376)
# ('Total diff between img', 4, 13, ' ', ' is ', 152.77488265992042)
# calculating 4 14...
# (264330, ' ', 43.02094650268126)
# ('Total diff between img', 4, 14, ' ', ' is ', 924.1209465026812)
# calculating 5 6...
# (46175, ' ', 43.07652409871159)
# ('Total diff between img', 5, 6, ' ', ' is ', 196.99319076537824)
# calculating 5 7...
# (117557, ' ', 37.41893641151341)
# ('Total diff between img', 5, 7, ' ', ' is ', 429.2756030781801)
# calculating 5 8...
# (38268, ' ', 49.03016281128649)
# ('Total diff between img', 5, 8, ' ', ' is ', 176.5901628112865)
# calculating 5 9...
# (150930, ' ', 40.284434000655416)
# ('Total diff between img', 5, 9, ' ', ' is ', 543.3844340006555)
# calculating 5 10...
# (22854, ' ', 42.03839111325829)
# ('Total diff between img', 5, 10, ' ', ' is ', 118.21839111325829)
# calculating 5 11...
# (101418, ' ', 41.15389124551883)
# ('Total diff between img', 5, 11, ' ', ' is ', 379.2138912455188)
# calculating 5 12...
# (35789, ' ', 41.14707056681698)
# ('Total diff between img', 5, 12, ' ', ' is ', 160.44373723348366)
# calculating 5 13...
# (32013, ' ', 39.546727498385295)
# ('Total diff between img', 5, 13, ' ', ' is ', 146.2567274983853)
# calculating 5 14...
# (327158, ' ', 40.8481038411415)
# ('Total diff between img', 5, 14, ' ', ' is ', 1131.374770507808)
# calculating 6 7...
# (37850, ' ', 44.52014668782564)
# ('Total diff between img', 6, 7, ' ', ' is ', 170.6868133544923)
# calculating 6 8...
# (14789, ' ', 43.955917358398914)
# ('Total diff between img', 6, 8, ' ', ' is ', 93.25258402506557)
# calculating 6 9...
# (84561, ' ', 42.694563547770514)
# ('Total diff between img', 6, 9, ' ', ' is ', 324.5645635477705)
# calculating 6 10...
# (90071, ' ', 43.44884618123331)
# ('Total diff between img', 6, 10, ' ', ' is ', 343.6855128479)
# calculating 6 11...
# (45567, ' ', 41.52853902180909)
# ('Total diff between img', 6, 11, ' ', ' is ', 193.41853902180907)
# calculating 6 12...
# (21960, ' ', 49.21996053059891)
# ('Total diff between img', 6, 12, ' ', ' is ', 122.41996053059891)
# calculating 6 13...
# (37790, ' ', 41.31623204549204)
# ('Total diff between img', 6, 13, ' ', ' is ', 167.28289871215873)
# calculating 6 14...
# (163229, ' ', 43.28394953409854)
# ('Total diff between img', 6, 14, ' ', ' is ', 587.3806162007652)
# calculating 7 8...
# (37039, ' ', 44.71278889973565)
# ('Total diff between img', 7, 8, ' ', ' is ', 168.17612223306898)
# calculating 7 9...
# (42071, ' ', 44.990823109940614)
# ('Total diff between img', 7, 9, ' ', ' is ', 185.22748977660729)
# calculating 7 10...
# (175031, ' ', 46.148751576752076)
# ('Total diff between img', 7, 10, ' ', ' is ', 629.5854182434186)
# calculating 7 11...
# (19661, ' ', 41.12427775065344)
# ('Total diff between img', 7, 11, ' ', ' is ', 106.66094441732011)
# calculating 7 12...
# (61008, ' ', 47.011337280231494)
# ('Total diff between img', 7, 12, ' ', ' is ', 250.3713372802315)
# calculating 7 13...
# (133686, ' ', 37.99367650348862)
# ('Total diff between img', 7, 13, ' ', ' is ', 483.61367650348865)
# calculating 7 14...
# (92423, ' ', 41.2807299296062)
# ('Total diff between img', 7, 14, ' ', ' is ', 349.35739659627285)
# calculating 8 9...
# (73102, ' ', 42.81709671020512)
# ('Total diff between img', 8, 9, ' ', ' is ', 286.4904300435385)
# calculating 8 10...
# (79630, ' ', 40.28134028116054)
# ('Total diff between img', 8, 10, ' ', ' is ', 305.7146736144939)
# calculating 8 11...
# (42744, ' ', 43.607126871744676)
# ('Total diff between img', 8, 11, ' ', ' is ', 186.08712687174466)
# calculating 8 12...
# (14449, ' ', 42.39913431802908)
# ('Total diff between img', 8, 12, ' ', ' is ', 90.56246765136241)
# calculating 8 13...
# (61573, ' ', 42.772424062090714)
# ('Total diff between img', 8, 13, ' ', ' is ', 248.01575739542406)
# calculating 8 14...
# (168388, ' ', 44.04775873820199)
# ('Total diff between img', 8, 14, ' ', ' is ', 605.3410920715353)
# calculating 9 10...
# (169458, ' ', 43.212941487627894)
# ('Total diff between img', 9, 10, ' ', ' is ', 608.0729414876279)
# calculating 9 11...
# (17268, ' ', 42.640941619873715)
# ('Total diff between img', 9, 11, ' ', ' is ', 100.20094161987372)
# calculating 9 12...
# (63589, ' ', 38.45443344116106)
# ('Total diff between img', 9, 12, ' ', ' is ', 250.4177667744944)
# calculating 9 13...
# (190575, ' ', 41.254806518557245)
# ('Total diff between img', 9, 13, ' ', ' is ', 676.5048065185572)
# calculating 9 14...
# (75410, ' ', 42.90937296549432)
# ('Total diff between img', 9, 14, ' ', ' is ', 294.276039632161)
# calculating 10 11...
# (135716, ' ', 41.79876836140936)
# ('Total diff between img', 10, 11, ' ', ' is ', 494.18543502807603)
# calculating 10 12...
# (51843, ' ', 39.59175237020283)
# ('Total diff between img', 10, 12, ' ', ' is ', 212.40175237020284)
# calculating 10 13...
# (48783, ' ', 41.47122701008776)
# ('Total diff between img', 10, 13, ' ', ' is ', 204.0812270100878)
# calculating 10 14...
# (390040, ' ', 41.22930908203209)
# ('Total diff between img', 10, 14, ' ', ' is ', 1341.3626424153656)
# calculating 11 12...
# (50165, ' ', 42.40886942544858)
# ('Total diff between img', 11, 12, ' ', ' is ', 209.62553609211525)
# calculating 11 13...
# (135313, ' ', 44.63339614868153)
# ('Total diff between img', 11, 13, ' ', ' is ', 495.6767294820149)
# calculating 11 14...
# (95918, ' ', 44.68770217895515)
# ('Total diff between img', 11, 14, ' ', ' is ', 364.4143688456218)
# calculating 12 13...
# (50776, ' ', 36.654865264909404)
# ('Total diff between img', 12, 13, ' ', ' is ', 205.90819859824273)
# calculating 12 14...
# (181623, ' ', 41.58579889932772)
# ('Total diff between img', 12, 14, ' ', ' is ', 646.9957988993277)
# calculating 13 14...
# (333375, ' ', 43.12461853027357)
# ('Total diff between img', 13, 14, ' ', ' is ', 1154.3746185302737)

# %%
print(seq)
for i in range(len(seq)):
	if i != len(seq)-1:
		halfway = generateMorphBarycentric(seq[i],seq[i+1])
		finalImg = np.concatenate((finalImg,halfway),axis=1)
		rhsImg = cv2.imread('./dataSet/test_' + str(seq[i+1])+'.png')
		finalImg = np.concatenate((finalImg,rhsImg),axis=1)

cv2.imwrite(str(endIndex) + 'Best Morph' + '.jpg',finalImg)
# Out:
# [13, 10, 5, 4, 12, 8, 6, 2, 3, 0, 7, 11, 9, 1, 14]
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# Generating the morph of alpha=0.5...
# True
